# %%
import numpy as np
import pandas as pd
import os

#mengimport library numpy dan diinisialisasikan dengan nama np, untuk pandas bernama pd

# %%
df = pd.read_json('rtiktok.json',lines="True")
df.head(1000)
# Out:
#                               _type  \
# 0    snscrape.modules.twitter.Tweet
# 1    snscrape.modules.twitter.Tweet
# 2    snscrape.modules.twitter.Tweet
# 3    snscrape.modules.twitter.Tweet
# 4    snscrape.modules.twitter.Tweet
# ..                              ...
# 995  snscrape.modules.twitter.Tweet
# 996  snscrape.modules.twitter.Tweet
# 997  snscrape.modules.twitter.Tweet
# 998  snscrape.modules.twitter.Tweet
# 999  snscrape.modules.twitter.Tweet
#
#                                                    url  \
# 0    https://twitter.com/CahayaAsyiqin_/status/1454...
# 1    https://twitter.com/positiviev/status/14544432...
# 2    https://twitter.com/zaaharysulaiman/status/145...
# 3    https://twitter.com/heppy_indra_/status/145436...
# 4    https://twitter.com/marklmies/status/145413036...
# ..                                                 ...
# 995  https://twitter.com/DreW_JaKoB_WolF/status/141...
# 996  https://twitter.com/azrulrendra/status/1419540...
# ...

# %%
data.head(100)
# Out:
#                              _type  \
# 0   snscrape.modules.twitter.Tweet
# 1   snscrape.modules.twitter.Tweet
# 2   snscrape.modules.twitter.Tweet
# 3   snscrape.modules.twitter.Tweet
# 4   snscrape.modules.twitter.Tweet
# ..                             ...
# 95  snscrape.modules.twitter.Tweet
# 96  snscrape.modules.twitter.Tweet
# 97  snscrape.modules.twitter.Tweet
# 98  snscrape.modules.twitter.Tweet
# 99  snscrape.modules.twitter.Tweet
#
#                                                   url  \
# 0   https://twitter.com/CahayaAsyiqin_/status/1454...
# 1   https://twitter.com/positiviev/status/14544432...
# 2   https://twitter.com/zaaharysulaiman/status/145...
# 3   https://twitter.com/heppy_indra_/status/145436...
# 4   https://twitter.com/marklmies/status/145413036...
# ..                                                ...
# 95  https://twitter.com/Xcueziro/status/1448833437...
# 96  https://twitter.com/yudiuuppp/status/144878471...
# ...

# %%
out = data.to_json(orient='records',lines=True)
with open('hasil.json', 'w') as f:
    f.write(out)

# %%
df1 = pd.read_json('hasil.json',lines="True")
data1 = df1.head(1000)
